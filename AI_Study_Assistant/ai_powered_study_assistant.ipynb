# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilamate/LLM_Course/blob/main/ai_powered_study_assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install GenAi Library

# %%
# !pip install -U google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.58.0 which is incompatible.
# ...

# %% [markdown]
# Import Libraries and Access the API Key

# %%
from google import genai
from google.colab import userdata

get_api_key = userdata.get('GEMINI_API_SECRET')
client = genai.Client(api_key = get_api_key)
print(client)

# %% [markdown]
# Create the Study Assistant Function

# %%
def study_assistant(user_prompt):
  response = client.models.generate_content(
      model = "gemini-2.5-flash",
      contents = user_prompt
  )
  return response

# %%
user_question = "Explain Generative AI in simple terms"
output = study_assistant(user_question)
print(output.text)
# Out:
# Imagine you have a super talented **creative assistant** who has studied *millions* of examples of art, writing, music, code, and more.
#
# Here's how Generative AI works in simple terms:
#
# 1.  **It Learns the "Rules" (without being explicitly told them):**
#     *   This AI isn't programmed with a list of instructions like "a dog has four legs, a tail, and barks."
#     *   Instead, it's shown **massive amounts of existing data** (e.g., millions of pictures of dogs, millions of poems, millions of songs).
#     *   By looking at all this data, it starts to understand the **patterns, styles, structures, and relationships** within it. It learns what a dog "looks like" by seeing countless examples, or what a "poetic style" sounds like by reading endless poems.
#
# 2.  **You Give it a Request (a "Prompt"):**
#     *   Once it's learned, you can ask it to create something new. This request is called a "prompt."
#     *   For example, you could say:
# ...
